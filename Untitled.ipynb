# %%
CONSUMER_KEY = "tkwFHzwkhyo8bIeOSXH1L8omi"
CONSUMER_SECRET = "wX36IckYPb14NYBKkvOKs2Z1RMZljw0IohgvXrP6BDOH7dqiiS"
ACCESS_TOKEN = "1399964730-kkZsDRUu6u6W6hpB0atD7soC1C4bdIg2NElIwVB"
ACCESS_TOKEN_SECRET = "foUyvX3iw7lYysCZRD3qXHaXtzM7RkyvJWdUcL3LdnyZV"
import tweepy
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
print(auth)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
print(auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET))
api = tweepy.API(auth,wait_on_rate_limit = True)
user = input("「@ユーザー名」を入力してください：")
followerIDs = api.followers_ids(user)
followerDatas = []
for followerID in followerIDs:
    followerData = {}
    data = api.get_user(followerID)
    followerData["Name"] = data.name
    followerData["ID"] = data.screen_name
    followerData["Follow"] = data.friends_count
    followerData["Follower"] = data.followers_count
    followerData["Description"] = data.description
    followerData["TweetCount"] = data.statuses_count
    followerDatas.append(followerData)
    print(followerData)
import pandas as pd
pd.set_option("display.max_rows", 1000)
df = pd.DataFrame(followerDatas).loc[:,["Name","ID","Follow","Follower","TweetCount","Description"]]
#ファイル出力
fileName = input("ファイル名を入力してください：")
df.to_csv(fileName + ".csv")
print("「" + fileName + ".csv」が作成されました。")
# Out:
# ...
# None
# 「@ユーザー名」を入力してください：@djtokyo
# {'Name': 'Hiroki Matsumoto', 'ID': 'junju', 'Follow': 2780, 'Follower': 896, 'Description': '', 'TweetCount': 11809}
# {'Name': '組織人事コンサル', 'ID': 'btr0604', 'Follow': 72, 'Follower': 26, 'Description': '組織人事系コンサル会社代表取締役。\n\n「マイクロラーニング」「組織の知」「戦略的人事」「マーケティングと人事制度」「インナーコミュニケーション」等について考え続けています。', 'TweetCount': 121}
# {'Name': 'Kitaちゃん@@@！', 'ID': 'Kita52203608', 'Follow': 75, 'Follower': 0, 'Description': '', 'TweetCount': 0}
# {'Name': 'acckiey-inn', 'ID': 'AcckieyI', 'Follow': 52, 'Follower': 2, 'Description': '', 'TweetCount': 2}
# {'Name': 'dutongzhen', 'ID': 'dutongzhen', 'Follow': 63, 'Follower': 5, 'Description': '', 'TweetCount': 0}
# {'Name': 'isoppp', 'ID': 'isopppcom', 'Follow': 197, 'Follower': 145, 'Description': 'フリーランスxxエンジニア。日記時々エンジニア関連。主は生活や考え方の方が最近は多いです。2019まで東京でサウンドデザイナ→フロントエンドWeb転身→カナダUI Dev→福岡移住計画', 'TweetCount': 2932}
# {'Name': 'A', 'ID': 'A73691420', 'Follow': 128, 'Follower': 27, 'Description': '', 'TweetCount': 0}
# ...
